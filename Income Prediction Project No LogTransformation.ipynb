# %% [markdown]
# # Income Prediction Using Decision Tree Regression

# %% [markdown]
# ## Loading The Main Libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Data Collection

# %%
data = pd.read_csv('/content/data.csv')

# %%
data.head()
# Out:
#    Age Education_Level  Occupation  Number_of_Dependents Location  \
# 0   56        Master's  Technology                     5    Urban
# 1   69     High School     Finance                     0    Urban
# 2   46      Bachelor's  Technology                     1    Urban
# 3   32     High School      Others                     2    Urban
# 4   60      Bachelor's     Finance                     3    Urban
#
#    Work_Experience Marital_Status Employment_Status  Household_Size  \
# 0               21        Married         Full-time               7
# 1                4         Single         Full-time               7
# 2                1         Single         Full-time               7
# 3               32        Married         Full-time               1
# 4               15        Married     Self-employed               4
#
#   Homeownership_Status     Type_of_Housing  Gender  \
# 0                  Own           Apartment    Male
# 1                  Own           Apartment    Male
# 2                  Own  Single-family home  Female
# 3                  Own           Apartment  Female
# 4                  Own           Townhouse    Male
#
#   Primary_Mode_of_Transportation  Income
# 0                 Public transit   72510
# 1                         Biking   75462
# 2                            Car   71748
# 3                            Car   74520
# 4                        Walking  640210

# %% [markdown]
# ## EDA

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Age                             10000 non-null  int64
#  1   Education_Level                 10000 non-null  object
#  2   Occupation                      10000 non-null  object
#  3   Number_of_Dependents            10000 non-null  int64
#  4   Location                        10000 non-null  object
#  5   Work_Experience                 10000 non-null  int64
#  6   Marital_Status                  10000 non-null  object
#  7   Employment_Status               10000 non-null  object
#  8   Household_Size                  10000 non-null  int64
#  9   Homeownership_Status            10000 non-null  object
#  10  Type_of_Housing                 10000 non-null  object
#  11  Gender                          10000 non-null  object
#  12  Primary_Mode_of_Transportation  10000 non-null  object
#  13  Income                          10000 non-null  int64
# dtypes: int64(5), object(9)
# memory usage: 1.1+ MB

# %%
data.isna().sum()
# Out:
# Age                               0
# Education_Level                   0
# Occupation                        0
# Number_of_Dependents              0
# Location                          0
# Work_Experience                   0
# Marital_Status                    0
# Employment_Status                 0
# Household_Size                    0
# Homeownership_Status              0
# Type_of_Housing                   0
# Gender                            0
# Primary_Mode_of_Transportation    0
# Income                            0
# dtype: int64

# %%
data.nunique()
# Out:
# Age                                 53
# Education_Level                      4
# Occupation                           5
# Number_of_Dependents                 6
# Location                             3
# Work_Experience                     51
# Marital_Status                       3
# Employment_Status                    3
# Household_Size                       7
# Homeownership_Status                 2
# Type_of_Housing                      3
# Gender                               2
# Primary_Mode_of_Transportation       4
# Income                            7667
# dtype: int64

# %%
for col in data.drop('Income' , axis = 1).columns:
  print(data[col].value_counts())
# Out:
# Age
# 43    223
# 66    216
# 62    215
# 40    212
# 64    209
# 34    209
# 52    207
# 45    205
# 38    203
# 35    200
# 49    200
# 30    200
# 46    199
# 42    197
# 19    196
# 29    194
# 21    194
# 39    194
# 56    192
# 68    192
# 57    191
# 59    191
# 32    191
# 54    191
# 37    190
# 41    189
# 51    189
# 22    188
# 61    188
# 25    188
# 20    188
# 33    187
# 53    186
# 23    185
# 36    183
# 47    183
# 55    183
# 28    182
# 70    182
# 50    182
# 69    178
# 26    177
# 18    176
# 65    175
# 31    175
# 67    174
# 27    174
# 58    173
# 63    169
# 60    162
# 24    161
# 44    159
# 48    153
# Name: count, dtype: int64
# Education_Level
# Bachelor's     4058
# High School    2959
# Master's       2482
# Doctorate       501
# Name: count, dtype: int64
# Occupation
# Healthcare    3035
# Technology    2407
# Finance       1525
# Others        1521
# Education     1512
# Name: count, dtype: int64
# Number_of_Dependents
# 5    1745
# 3    1712
# 1    1651
# 0    1642
# 4    1629
# 2    1621
# Name: count, dtype: int64
# Location
# Urban       7037
# Suburban    1951
# Rural       1012
# Name: count, dtype: int64
# Work_Experience
# 2     224
# 44    221
# 48    219
# 24    218
# 33    216
# 21    215
# 35    215
# 27    213
# 37    213
# 29    212
# 39    210
# 18    209
# 1     208
# 20    207
# 15    205
# 8     205
# 40    204
# 26    203
# 4     200
# 22    200
# 10    200
# 5     198
# 36    198
# 17    197
# 9     196
# 45    193
# 42    192
# 0     192
# 3     191
# 11    191
# 13    190
# 6     190
# 14    190
# 28    189
# 41    189
# 16    188
# 32    187
# 43    187
# 49    186
# 25    186
# 38    184
# 19    184
# 23    183
# 30    183
# 47    182
# 34    181
# 12    180
# 31    179
# 7     175
# 50    167
# 46    155
# Name: count, dtype: int64
# Marital_Status
# Married     5136
# Single      3900
# Divorced     964
# Name: count, dtype: int64
# Employment_Status
# Full-time        5004
# Part-time        3016
# Self-employed    1980
# Name: count, dtype: int64
# Household_Size
# 1    1477
# 3    1445
# 6    1437
# 7    1433
# 5    1411
# 2    1406
# 4    1391
# Name: count, dtype: int64
# Homeownership_Status
# Own     6018
# Rent    3982
# Name: count, dtype: int64
# Type_of_Housing
# Single-family home    4055
# Apartment             4001
# Townhouse             1944
# Name: count, dtype: int64
# Gender
# Male      5123
# Female    4877
# Name: count, dtype: int64
# Primary_Mode_of_Transportation
# Public transit    4047
# Car               2986
# Biking            1940
# Walking           1027
# Name: count, dtype: int64

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Handling the missing values
#
#       - No missing values

# %% [markdown]
# ### Encoding the categorical variables

# %%
categorical_cols = data.select_dtypes( include = 'object' ).columns

display ( categorical_cols )
# Out:
# Index(['Education_Level', 'Occupation', 'Location', 'Marital_Status',
#        'Employment_Status', 'Homeownership_Status', 'Type_of_Housing',
#        'Gender', 'Primary_Mode_of_Transportation'],
#       dtype='object')

# %% [markdown]
#       ▶ categorical_cols = [ Occupation  ,  Location  ,  Marital_Status  , Employment_Status  ,  Homeownership_Status  ,
#
#       Type_of_Housing  ,  Gender  ,  Primary_Mode_of_Transportation  ,  Education_Level  ]
#
#
#       ▶ Encode the Education_Level using Ordinal Encoding  because it's an ordinal variable
#
#
#       ▶ Encode the reminder Using OneHot Encoding method

# %% [markdown]
#       ▶  First , We will Encode the Education_Level using Ordinal Encoding because it's an ordinal variable

# %%
data['Education_Level'].value_counts()
# Out:
# Education_Level
# Bachelor's     4058
# High School    2959
# Master's       2482
# Doctorate       501
# Name: count, dtype: int64

# %%
data['Education_Level'].head(10)
# Out:
# 0       Master's
# 1    High School
# 2     Bachelor's
# 3    High School
# 4     Bachelor's
# 5    High School
# 6       Master's
# 7       Master's
# 8       Master's
# 9     Bachelor's
# Name: Education_Level, dtype: object

# %%
data['Education_Level'].tail(10)
# Out:
# 9990     Bachelor's
# 9991     Bachelor's
# 9992       Master's
# 9993     Bachelor's
# 9994    High School
# 9995    High School
# 9996       Master's
# 9997      Doctorate
# 9998    High School
# 9999    High School
# Name: Education_Level, dtype: object

# %%
# Encode the Education_Level using Ordinal Encoding method because it's an ordinal variable

EducationLevelMap = {
    "High School": 0,
    "Bachelor's": 1,
    "Master's": 2,
    "Doctorate": 3
}

data['Education_Level'] = data['Education_Level'].map( EducationLevelMap )

# %%
data['Education_Level'].head(10)
# Out:
# 0    2
# 1    0
# 2    1
# 3    0
# 4    1
# 5    0
# 6    2
# 7    2
# 8    2
# 9    1
# Name: Education_Level, dtype: int64

# %%
data['Education_Level'].tail(10)
# Out:
# 9990    1
# 9991    1
# 9992    2
# 9993    1
# 9994    0
# 9995    0
# 9996    2
# 9997    3
# 9998    0
# 9999    0
# Name: Education_Level, dtype: int64

# %% [markdown]
#       ▶ Encoding the reminder categorical variables using OneHot Encoding
#
#       ▶ No need to drop any dummy columns after getting the dummy columns from the OneHot because the Decesion Tree Regression
#
#        isn't affected by the multicollinearity

# %%
categorical_cols = data.select_dtypes( include = 'object' ).columns

#categorical_cols

# %%
data = pd.get_dummies( data , columns = categorical_cols , dtype = int )      # OneHot Encoding for the reminder categorical columns

# %%
data.head()
# Out:
#    Age  Education_Level  Number_of_Dependents  Work_Experience  \
# 0   56                2                     5               21
# 1   69                0                     0                4
# 2   46                1                     1                1
# 3   32                0                     2               32
# 4   60                1                     3               15
#
#    Household_Size  Income  Occupation_Education  Occupation_Finance  \
# 0               7   72510                     0                   0
# 1               7   75462                     0                   1
# 2               7   71748                     0                   0
# 3               1   74520                     0                   0
# 4               4  640210                     0                   1
#
#    Occupation_Healthcare  Occupation_Others  ...  Homeownership_Status_Rent  \
# 0                      0                  0  ...                          0
# 1                      0                  0  ...                          0
# 2                      0                  0  ...                          0
# 3                      0                  1  ...                          0
# 4                      0                  0  ...                          0
#
#    Type_of_Housing_Apartment  Type_of_Housing_Single-family home  \
# 0                          1                                   0
# 1                          1                                   0
# 2                          0                                   1
# 3                          1                                   0
# 4                          0                                   0
#
#    Type_of_Housing_Townhouse  Gender_Female  Gender_Male  \
# 0                          0              0            1
# 1                          0              0            1
# 2                          0              1            0
# 3                          0              1            0
# 4                          1              0            1
#
#    Primary_Mode_of_Transportation_Biking  Primary_Mode_of_Transportation_Car  \
# 0                                      0                                   0
# 1                                      1                                   0
# 2                                      0                                   1
# 3                                      0                                   1
# 4                                      0                                   0
#
#    Primary_Mode_of_Transportation_Public transit  \
# 0                                              1
# 1                                              0
# 2                                              0
# 3                                              0
# 4                                              0
#
#    Primary_Mode_of_Transportation_Walking
# 0                                       0
# 1                                       0
# 2                                       0
# 3                                       0
# 4                                       1
#
# [5 rows x 31 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 31 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Age                                            10000 non-null  int64
#  1   Education_Level                                10000 non-null  int64
#  2   Number_of_Dependents                           10000 non-null  int64
#  3   Work_Experience                                10000 non-null  int64
#  4   Household_Size                                 10000 non-null  int64
#  5   Income                                         10000 non-null  int64
#  6   Occupation_Education                           10000 non-null  int64
#  7   Occupation_Finance                             10000 non-null  int64
#  8   Occupation_Healthcare                          10000 non-null  int64
#  9   Occupation_Others                              10000 non-null  int64
#  10  Occupation_Technology                          10000 non-null  int64
#  11  Location_Rural                                 10000 non-null  int64
#  12  Location_Suburban                              10000 non-null  int64
#  13  Location_Urban                                 10000 non-null  int64
#  14  Marital_Status_Divorced                        10000 non-null  int64
#  15  Marital_Status_Married                         10000 non-null  int64
#  16  Marital_Status_Single                          10000 non-null  int64
#  17  Employment_Status_Full-time                    10000 non-null  int64
#  18  Employment_Status_Part-time                    10000 non-null  int64
#  19  Employment_Status_Self-employed                10000 non-null  int64
#  20  Homeownership_Status_Own                       10000 non-null  int64
#  21  Homeownership_Status_Rent                      10000 non-null  int64
#  22  Type_of_Housing_Apartment                      10000 non-null  int64
#  23  Type_of_Housing_Single-family home             10000 non-null  int64
#  24  Type_of_Housing_Townhouse                      10000 non-null  int64
#  25  Gender_Female                                  10000 non-null  int64
#  26  Gender_Male                                    10000 non-null  int64
#  27  Primary_Mode_of_Transportation_Biking          10000 non-null  int64
#  28  Primary_Mode_of_Transportation_Car             10000 non-null  int64
#  29  Primary_Mode_of_Transportation_Public transit  10000 non-null  int64
#  30  Primary_Mode_of_Transportation_Walking         10000 non-null  int64
# dtypes: int64(31)
# memory usage: 2.4 MB

# %% [markdown]
# .
#
# ### Splitting the Data into input & output

# %%
x = data.drop('Income' , axis = 1)
y = data['Income']

# %%
x.head()
# Out:
#    Age  Education_Level  Number_of_Dependents  Work_Experience  \
# 0   56                2                     5               21
# 1   69                0                     0                4
# 2   46                1                     1                1
# 3   32                0                     2               32
# 4   60                1                     3               15
#
#    Household_Size  Occupation_Education  Occupation_Finance  \
# 0               7                     0                   0
# 1               7                     0                   1
# 2               7                     0                   0
# 3               1                     0                   0
# 4               4                     0                   1
#
#    Occupation_Healthcare  Occupation_Others  Occupation_Technology  ...  \
# 0                      0                  0                      1  ...
# 1                      0                  0                      0  ...
# 2                      0                  0                      1  ...
# 3                      0                  1                      0  ...
# 4                      0                  0                      0  ...
#
#    Homeownership_Status_Rent  Type_of_Housing_Apartment  \
# 0                          0                          1
# 1                          0                          1
# 2                          0                          0
# 3                          0                          1
# 4                          0                          0
#
#    Type_of_Housing_Single-family home  Type_of_Housing_Townhouse  \
# 0                                   0                          0
# 1                                   0                          0
# 2                                   1                          0
# 3                                   0                          0
# 4                                   0                          1
#
#    Gender_Female  Gender_Male  Primary_Mode_of_Transportation_Biking  \
# 0              0            1                                      0
# 1              0            1                                      1
# 2              1            0                                      0
# 3              1            0                                      0
# 4              0            1                                      0
#
#    Primary_Mode_of_Transportation_Car  \
# 0                                   0
# 1                                   0
# 2                                   1
# 3                                   1
# 4                                   0
#
#    Primary_Mode_of_Transportation_Public transit  \
# 0                                              1
# 1                                              0
# 2                                              0
# 3                                              0
# 4                                              0
#
#    Primary_Mode_of_Transportation_Walking
# 0                                       0
# 1                                       0
# 2                                       0
# 3                                       0
# 4                                       1
#
# [5 rows x 30 columns]

# %%
y.head()
# Out:
# 0     72510
# 1     75462
# 2     71748
# 3     74520
# 4    640210
# Name: Income, dtype: int64

# %% [markdown]
# .
#
# ### Splitting the data into training and testing

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split ( x , y , test_size = 0.2 , random_state = 0 )

# %%
x_train.head()
# Out:
#       Age  Education_Level  Number_of_Dependents  Work_Experience  \
# 7389   42                0                     1               10
# 9275   19                1                     0               21
# 2995   49                2                     3               10
# 5316   68                2                     4                5
# 356    39                1                     4               37
#
#       Household_Size  Occupation_Education  Occupation_Finance  \
# 7389               2                     0                   0
# 9275               2                     0                   0
# 2995               4                     0                   0
# 5316               5                     0                   0
# 356                6                     0                   0
#
#       Occupation_Healthcare  Occupation_Others  Occupation_Technology  ...  \
# 7389                      0                  1                      0  ...
# 9275                      1                  0                      0  ...
# 2995                      0                  1                      0  ...
# 5316                      0                  1                      0  ...
# 356                       0                  1                      0  ...
#
#       Homeownership_Status_Rent  Type_of_Housing_Apartment  \
# 7389                          1                          1
# 9275                          1                          1
# 2995                          1                          0
# 5316                          1                          0
# 356                           0                          1
#
#       Type_of_Housing_Single-family home  Type_of_Housing_Townhouse  \
# 7389                                   0                          0
# 9275                                   0                          0
# 2995                                   0                          1
# 5316                                   1                          0
# 356                                    0                          0
#
#       Gender_Female  Gender_Male  Primary_Mode_of_Transportation_Biking  \
# 7389              0            1                                      1
# 9275              0            1                                      0
# 2995              0            1                                      0
# 5316              0            1                                      1
# 356               1            0                                      1
#
#       Primary_Mode_of_Transportation_Car  \
# 7389                                   0
# 9275                                   0
# 2995                                   0
# 5316                                   0
# 356                                    0
#
#       Primary_Mode_of_Transportation_Public transit  \
# 7389                                              0
# 9275                                              1
# 2995                                              1
# 5316                                              0
# 356                                               0
#
#       Primary_Mode_of_Transportation_Walking
# 7389                                       0
# 9275                                       0
# 2995                                       0
# 5316                                       0
# 356                                        0
#
# [5 rows x 30 columns]

# %%
y_train.head()
# Out:
# 7389      71692
# 9275     279059
# 2995     280479
# 5316    2280108
# 356     2771585
# Name: Income, dtype: int64

# %%
x_test.head()
# Out:
#       Age  Education_Level  Number_of_Dependents  Work_Experience  \
# 9394   69                0                     3               34
# 898    31                1                     1               47
# 2398   19                0                     0               42
# 5906   55                2                     4               29
# 2343   67                0                     0               49
#
#       Household_Size  Occupation_Education  Occupation_Finance  \
# 9394               5                     1                   0
# 898                2                     0                   1
# 2398               3                     0                   0
# 5906               6                     0                   0
# 2343               1                     1                   0
#
#       Occupation_Healthcare  Occupation_Others  Occupation_Technology  ...  \
# 9394                      0                  0                      0  ...
# 898                       0                  0                      0  ...
# 2398                      1                  0                      0  ...
# 5906                      1                  0                      0  ...
# 2343                      0                  0                      0  ...
#
#       Homeownership_Status_Rent  Type_of_Housing_Apartment  \
# 9394                          0                          0
# 898                           0                          1
# 2398                          0                          1
# 5906                          0                          0
# 2343                          0                          0
#
#       Type_of_Housing_Single-family home  Type_of_Housing_Townhouse  \
# 9394                                   0                          1
# 898                                    0                          0
# 2398                                   0                          0
# 5906                                   0                          1
# 2343                                   1                          0
#
#       Gender_Female  Gender_Male  Primary_Mode_of_Transportation_Biking  \
# 9394              0            1                                      0
# 898               1            0                                      0
# 2398              0            1                                      0
# 5906              0            1                                      1
# 2343              1            0                                      1
#
#       Primary_Mode_of_Transportation_Car  \
# 9394                                   1
# 898                                    1
# 2398                                   1
# 5906                                   0
# 2343                                   0
#
#       Primary_Mode_of_Transportation_Public transit  \
# 9394                                              0
# 898                                               0
# 2398                                              0
# 5906                                              0
# 2343                                              0
#
#       Primary_Mode_of_Transportation_Walking
# 9394                                       0
# 898                                        0
# 2398                                       0
# 5906                                       0
# 2343                                       0
#
# [5 rows x 30 columns]

# %%
y_test.head()
# Out:
# 9394    74532
# 898     65380
# 2398    67508
# 5906    67726
# 2343    67574
# Name: Income, dtype: int64

# %%
x_train = x_train.values
y_train = y_train.values
x_test  = x_test.values
y_test  = y_test.values

# %%
x_train
# Out:
# array([[42,  0,  1, ...,  0,  0,  0],
#        [19,  1,  0, ...,  0,  1,  0],
#        [49,  2,  3, ...,  0,  1,  0],
#        ...,
#        [54,  1,  4, ...,  0,  1,  0],
#        [37,  1,  1, ...,  0,  1,  0],
#        [26,  1,  3, ...,  0,  0,  1]])

# %% [markdown]
# ## Feature Selection
#
#       ▶ Decision Tree Regression is not affected by the multicollinearity so even if there is a non important features it will not
#
#       split from it so it will be ignored

# %% [markdown]
# ## Model Training

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV

# %%
dtree = DecisionTreeRegressor( random_state = 0 )

# %%
param_grid = {
    'max_depth': [ 2, 3 , 4, 5 , 6 , 7 , 8, 10, 12, 14, 16 , None ],
    'min_samples_leaf': [1, 2, 3, 4, 5, 6, 7, 8],
    'min_samples_split': [2, 3, 4, 5, 6, 7, 8, 9, 10]
}

# %%
getBestTree = GridSearchCV( estimator = dtree , param_grid = param_grid , cv = 5 , scoring = 'neg_mean_squared_error' , n_jobs = -1 , verbose = 2 )

getBestTree.fit( x_train , y_train )

print("GridSearchCV completed successfully and best hyperparameters have been identified.")
print("Best Found Max Depth From GridSearchCV Is:", getBestTree.best_params_)
print("Best Average CV score:", -1 * getBestTree.best_score_ , '\n' )
# Out:
# Fitting 5 folds for each of 864 candidates, totalling 4320 fits
# GridSearchCV completed successfully and best hyperparameters have been identified.
# Best Found Max Depth From GridSearchCV Is: {'max_depth': 5, 'min_samples_leaf': 6, 'min_samples_split': 2}
# Best Average CV score: 3276736359897.236

# %%
regressor =  getBestTree.best_estimator_                # our final best trained model

# %%
predictedIncome = regressor.predict( x_test )

# %% [markdown]
# ### Model Evaluation

# %%
from sklearn.metrics import mean_squared_error , r2_score

# %% [markdown]
# ### Evaluate Training results

# %%
predicted_training_income = regressor.predict( x_train )

training_data_results = pd.DataFrame(x_train, columns=x.columns)
training_data_results['True_Income'] = y_train
training_data_results['Predicted_Income'] =  np.round( predicted_training_income )

training_data_results.head()
# Out:
#    Age  Education_Level  Number_of_Dependents  Work_Experience  \
# 0   42                0                     1               10
# 1   19                1                     0               21
# 2   49                2                     3               10
# 3   68                2                     4                5
# 4   39                1                     4               37
#
#    Household_Size  Occupation_Education  Occupation_Finance  \
# 0               2                     0                   0
# 1               2                     0                   0
# 2               4                     0                   0
# 3               5                     0                   0
# 4               6                     0                   0
#
#    Occupation_Healthcare  Occupation_Others  Occupation_Technology  ...  \
# 0                      0                  1                      0  ...
# 1                      1                  0                      0  ...
# 2                      0                  1                      0  ...
# 3                      0                  1                      0  ...
# 4                      0                  1                      0  ...
#
#    Type_of_Housing_Single-family home  Type_of_Housing_Townhouse  \
# 0                                   0                          0
# 1                                   0                          0
# 2                                   0                          1
# 3                                   1                          0
# 4                                   0                          0
#
#    Gender_Female  Gender_Male  Primary_Mode_of_Transportation_Biking  \
# 0              0            1                                      1
# 1              0            1                                      0
# 2              0            1                                      0
# 3              0            1                                      1
# 4              1            0                                      1
#
#    Primary_Mode_of_Transportation_Car  \
# 0                                   0
# 1                                   0
# 2                                   0
# 3                                   0
# 4                                   0
#
#    Primary_Mode_of_Transportation_Public transit  \
# 0                                              0
# 1                                              1
# 2                                              1
# 3                                              0
# 4                                              0
#
#    Primary_Mode_of_Transportation_Walking  True_Income  Predicted_Income
# 0                                       0        71692          980007.0
# 1                                       0       279059         1078697.0
# 2                                       0       280479          753307.0
# 3                                       0      2280108          753307.0
# 4                                       0      2771585         1165311.0
#
# [5 rows x 32 columns]

# %%
training_mse = mean_squared_error( y_train , predicted_training_income )
training_r2 = r2_score( y_train , predicted_training_income )

print(f"Training Mean Squared Error: {training_mse:.2f}")
print(f"Training R-squared: {training_r2*100:.2f}")
# Out:
# Training Mean Squared Error: 3161872442014.46
# Training R-squared: 5.46

# %% [markdown]
# ### Evaluating the test results

# %%
test_data_results = pd.DataFrame(x_test, columns=x.columns)
test_data_results['True_Income'] = y_test
test_data_results['Predicted_Income'] = np.round( predictedIncome )

test_data_results.head()
# Out:
#    Age  Education_Level  Number_of_Dependents  Work_Experience  \
# 0   69                0                     3               34
# 1   31                1                     1               47
# 2   19                0                     0               42
# 3   55                2                     4               29
# 4   67                0                     0               49
#
#    Household_Size  Occupation_Education  Occupation_Finance  \
# 0               5                     1                   0
# 1               2                     0                   1
# 2               3                     0                   0
# 3               6                     0                   0
# 4               1                     1                   0
#
#    Occupation_Healthcare  Occupation_Others  Occupation_Technology  ...  \
# 0                      0                  0                      0  ...
# 1                      0                  0                      0  ...
# 2                      1                  0                      0  ...
# 3                      1                  0                      0  ...
# 4                      0                  0                      0  ...
#
#    Type_of_Housing_Single-family home  Type_of_Housing_Townhouse  \
# 0                                   0                          1
# 1                                   0                          0
# 2                                   0                          0
# 3                                   0                          1
# 4                                   1                          0
#
#    Gender_Female  Gender_Male  Primary_Mode_of_Transportation_Biking  \
# 0              0            1                                      0
# 1              1            0                                      0
# 2              0            1                                      0
# 3              0            1                                      1
# 4              1            0                                      1
#
#    Primary_Mode_of_Transportation_Car  \
# 0                                   1
# 1                                   1
# 2                                   1
# 3                                   0
# 4                                   0
#
#    Primary_Mode_of_Transportation_Public transit  \
# 0                                              0
# 1                                              0
# 2                                              0
# 3                                              0
# 4                                              0
#
#    Primary_Mode_of_Transportation_Walking  True_Income  Predicted_Income
# 0                                       0        74532          386100.0
# 1                                       0        65380          882102.0
# 2                                       0        67508         1165311.0
# 3                                       0        67726          435386.0
# 4                                       0        67574          386100.0
#
# [5 rows x 32 columns]

# %%
testingMse = mean_squared_error( y_test , predictedIncome )
testingR2  = r2_score( y_test , predictedIncome )

print(f"Testing Mean Squared Error: {testingMse:.2f}")
print(f"Testing R-squared: {testingR2*100:.2f}%")
# Out:
# Testing Mean Squared Error: 3147598795689.65
# Testing R-squared: 1.68
